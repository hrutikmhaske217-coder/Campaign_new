# %% [markdown]
# # Project Title:
# ### Data-Driven Ad Campaign Optimization

# %% [markdown]
# # Project Domain:
# ### Digital Marketing Analytics

# %% [markdown]
# # Problem Statement
#
#
# The objective of this project is to analyze and optimize digital ad campaigns using data-driven techniques. The primary goal is to identify and evaluate Key Performance Indicators (KPIs) such as CTR, CVR, CPC, and ROAS that significantly influence campaign effectiveness. By applying exploratory data analysis (EDA), feature engineering, and statistical methods, we aim to generate actionable insights that can guide marketing teams to improve campaign engagement, increase conversions, and maximize Return on Investment (ROI).

# %% [markdown]
# # Role
# ### Data Analyst
# Responsible for
# - data cleaning,
# - exploration,
# - statistical analysis,
# - visualization,
# - insight generation

# %% [markdown]
# # Tools & Technologies
# 1) Python (Pandas, NumPy, Matplotlib, Seaborn, Plotly)
# 2) Jupyter Notebook / VS Code
# 3) MySQL (for querying structured data)
# 4) Excel (for basic dashboarding if needed)
# 5) Power BI or Tableau (optional, for visualization dashboard)

# %% [markdown]
# # Step 1: Data Collection / Import

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from datetime import datetime

# %%
df=pd.read_csv(r"c:\Users\ADMIN\Downloads\ad_campaign_completely_raw_dataset (1).csv")
df
# Out:
#       campaign_id      campaign_name      platform            date  \
# 0            1001        Summer Sale       Unknown  March 10, 2024
# 1            1002                !!!  Facebook Ads      15-02-2024
# 2            1003                NaN           NaN             NaN
# 3            1004        Summer Sale     Gogle Adz      15-02-2024
# 4            1005  Black Friday Deal    Google Ads  March 10, 2024
# ...           ...                ...           ...             ...
# 1195         1732        Summer Sale        FB ads      2024/04/05
# 1196         1100   Unknown_campaign           NaN      2024/04/05
# 1197         1099                NaN     Gogle Adz      2024-01-01
# 1198         1678   Unknown_campaign        FB ads      2024/04/05
# 1199         1829  Black Friday Deal  Facebook Ads      2024-01-01
#
#       impressions clicks    cost  conversions  revenue    ctr  ...  \
# 0         33144.0   1836  428.66        494.0  3697.13   5.54  ...
# ...

# %%
df.describe()
# Out:
#        campaign_id   impressions         cost  conversions      revenue  \
# count  1200.000000   1195.000000  1192.000000  1193.000000  1194.000000
# mean   1502.479167  27658.066946   265.122659   249.744342  2778.121039
# std     287.972886  13083.905300   131.358002   141.854375  1301.767604
# min    1001.000000   5054.000000    50.200000    10.000000   508.070000
# 25%    1250.750000  16173.500000   140.575000   131.000000  1648.747500
# 50%    1505.000000  27782.000000   255.875000   241.000000  2738.860000
# 75%    1749.250000  39147.500000   378.585000   375.000000  3914.715000
# max    2000.000000  49865.000000   499.900000   499.000000  4997.340000
#
#                ctr          cpc  conversion_rate         roas  bounce_rate  \
# count  1189.000000  1189.000000      1189.000000  1192.000000  1195.000000
# mean     12.971985     0.228545        20.339403    15.044908    34.321339
# std      12.724070     0.430080        35.806968    13.792969     8.727717
# ...

# %%
df.sample()
# Out:
#      campaign_id     campaign_name    platform       date  impressions  \
# 163         1164  Unknown_campaign  google_ads 2024-01-01      21519.0
#
#      clicks    cost  conversions  revenue    ctr  ...  conversion_rate  roas  \
# 163  4895.0  325.85        107.0   838.38  22.75  ...             2.19  2.57
#
#         ad_type audience_segment device_type region bounce_rate  \
# 163  search_add              NaN      Mobile  India        24.0
#
#      avg_session_duration engagement_rate  ad_position
# 163                   NaN            43.0          NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# # Step 2: Data Cleaning:

# %% [markdown]
# ## 1.1 Initial Inspection (Before Cleaning Starts)
# Method:
# df.head(), df.tail(), df.sample()
#
# df.info() → data types + nulls
#
# df.describe() → numeric summary
#
# df.columns → column names check
#
# Goal: Data structure, size, आणि problems समजून घेणं.

# %%
df.head()
# Out:
#    campaign_id      campaign_name      platform       date  impressions  \
# 0         1001        Summer Sale       Unknown 2024-03-10      33144.0
# 1         1002                !!!  Facebook Ads 2024-02-15      32780.0
# 2         1003                NaN           NaN 2024-02-15      28847.0
# 3         1004        Summer Sale     Gogle Adz 2024-02-15      21367.0
# 4         1005  Black Friday Deal    Google Ads 2024-03-10      36303.0
#
#    clicks    cost  conversions  revenue    ctr  ...  conversion_rate   roas  \
# 0  1836.0  428.66        494.0  3697.13   5.54  ...            26.91   8.62
# 1  1846.0  431.54         97.0  1834.94   5.63  ...             5.25   4.25
# 2  3890.0   85.31        261.0  4562.69  13.48  ...             6.71  53.48
# 3  4922.0  449.65        146.0  2968.74  23.04  ...             2.97   6.60
# 4  4947.0  176.97        313.0  3103.35  13.63  ...             6.33  17.54
#
#       ad_type     audience_segment device_type   region bounce_rate  \
# ...

# %%
# sarv column name lower case madhe ahe. ya thikane kahi null values ahet. numerical va catagorical donhi column ahet.
# impressions ky ahe te samjun ghene. what is conversion. what is roas. 
# there is some null values available in dataset. in some where there is unlown insted of nulls.

# %%
df.tail()
# Out:
#       campaign_id      campaign_name      platform        date  impressions  \
# 1195         1732        Summer Sale        FB ads  2024/04/05      36176.0
# 1196         1100   Unknown_campaign           NaN  2024/04/05      37920.0
# 1197         1099                NaN     Gogle Adz  2024-01-01       8537.0
# 1198         1678   Unknown_campaign        FB ads  2024/04/05       7547.0
# 1199         1829  Black Friday Deal  Facebook Ads  2024-01-01       7814.0
#
#      clicks    cost  conversions  revenue    ctr  ...  conversion_rate   roas  \
# 1195   4362  432.64        449.0  3731.56  12.06  ...            10.29   8.63
# 1196   4346  382.42        335.0  4444.86  11.46  ...             7.71  11.62
# 1197   1758  464.99        490.0  2155.98  20.59  ...            27.87   4.64
# 1198   4967  427.60        136.0  3809.75  65.81  ...             2.74   8.91
# 1199    773  405.51        220.0  2067.97   9.89  ...            28.46   5.10
#
# ...

# %%
# there is same observation like df.head()

# %%
df.sample()
# Out:
#      campaign_id campaign_name platform            date  impressions clicks  \
# 621         1622           !!!      NaN  March 10, 2024      15239.0    380
#
#        cost  conversions  revenue   ctr  ...  conversion_rate   roas  \
# 621  247.26        136.0  2973.48  2.49  ...            35.79  12.03
#
#       ad_type audience_segment device_type  region bounce_rate  \
# 621  Video Ad              NaN     Desktop  Europe        28.0
#
#      avg_session_duration engagement_rate  ad_position
# 621                   NaN            30.0       Bottom
#
# [1 rows x 21 columns]

# %%
# out of 21 column there is 13 is numerical column and remaining are catagorical column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   campaign_id           1200 non-null   int64
#  1   campaign_name         1004 non-null   object
#  2   platform              1030 non-null   object
#  3   date                  941 non-null    object
#  4   impressions           1195 non-null   float64
#  5   clicks                1200 non-null   object
#  6   cost                  1192 non-null   float64
#  7   conversions           1193 non-null   float64
#  8   revenue               1194 non-null   float64
#  9   ctr                   1189 non-null   float64
#  10  cpc                   1189 non-null   float64
#  11  conversion_rate       1189 non-null   float64
#  12  roas                  1192 non-null   float64
#  13  ad_type               979 non-null    object
# ...

# %%
# campaign id madhe, clicks ek pan null value nahiye. 
# 200 chya aspas null values 3 column(campaign_name,platform, device type). 
# cost to roas panryant je column ahet tyamadhe 10 to 20 null values ahet. 
# 300 chya aspas null vules( date, ad_type,audience_segment,region), 
# 400 chya asapass null values ad_possition madhe ahet. 
# sarvat jast null values avg_session_duration madhe ahet. 
# data type 3 prakarche ahet int. object, float.
# null value treat karavya lagatil 
# date column cha datatype object ahe tyala date madhe convert karave lagel
# clicks cha datatype object ahe tyala int madhe convert karave lagel
# avg session duration che formating karave lagel

# %%
# atta aplalyala deside karayache ahe ki sarvat jast null value asanara column avg_session_duration thevayacha ki nahi

# %%
df.columns
# Out:
# Index(['campaign_id', 'campaign_name', 'platform', 'date', 'impressions',
#        'clicks', 'cost', 'conversions', 'revenue', 'ctr', 'cpc',
#        'conversion_rate', 'roas', 'ad_type', 'audience_segment', 'device_type',
#        'region', 'bounce_rate', 'avg_session_duration', 'engagement_rate',
#        'ad_position'],
#       dtype='object')

# %%
df['clicks']
# Out:
# 0       1836
# 1       1846
# 2       3890
# 3       4922
# 4       4947
#         ...
# 1195    4362
# 1196    4346
# 1197    1758
# 1198    4967
# 1199     773
# Name: clicks, Length: 1200, dtype: object

# %%
null_percentage=df['clicks'].isnull().mean()*100
print('missing=',null_percentage)
# Out:
# missing= 0.0

# %%
null_pecentage=df['avg_session_duration'].isnull().mean()*100
print('missing=',null_pecentage)
# Out:
# missing= 53.25

# %%
# mhange 53% value null ahet tr shakyato to column thevaycha praytn karava. khupach 70% value null asatil tr drop karava

# %%
# date column cha data type change karuya

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
df['date']
# Out:
# 0       March 10, 2024
# 1           15-02-2024
# 2                  NaN
# 3           15-02-2024
# 4       March 10, 2024
#              ...
# 1195        2024/04/05
# 1196        2024/04/05
# 1197        2024-01-01
# 1198        2024/04/05
# 1199        2024-01-01
# Name: date, Length: 1200, dtype: object

# %%
df['date'].unique()
# Out:
# array(['March 10, 2024', '15-02-2024', nan, '2024/04/05', '2024-01-01'],
#       dtype=object)

# %%
df.loc[df['date'] == 'March 10, 2024', 'date'] = '10-03-2024'
df.loc[df['date'] == '2024/04/05', 'date'] = '05-04-2024'
df.loc[df['date'] == '2024-01-01', 'date'] = '01-01-2024'
df['date'].unique()
# Out:
# array(['10-03-2024', '15-02-2024', nan, '05-04-2024', '01-01-2024'],
#       dtype=object)

# %%
df['date']=df['date'].fillna(method='bfill')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13220\2489334493.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['date']=df['date'].fillna(method='bfill')

# %%
df['date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['date']
# Out:
# 0       10-03-2024
# 1       15-02-2024
# 2       15-02-2024
# 3       15-02-2024
# 4       10-03-2024
#            ...
# 1195    05-04-2024
# 1196    05-04-2024
# 1197    01-01-2024
# 1198    05-04-2024
# 1199    01-01-2024
# Name: date, Length: 1200, dtype: object

# %%
# Convert from string (object) to datetime, specifying dayfirst=True
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y', errors='coerce')

# %%
df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#  atta clicks column baghu

# %%
df['clicks']
# Out:
# 0       1836
# 1       1846
# 2       3890
# 3       4922
# 4       4947
#         ...
# 1195    4362
# 1196    4346
# 1197    1758
# 1198    4967
# 1199     773
# Name: clicks, Length: 1200, dtype: object

# %%
df['clicks'].unique()
# Out:
# array(['1836', '1846', '3890', '4922', '4947', '2811', '3797', '3659',
#        '1180', '789', '475', '130', '4607', '3419', '1328', '1880',
#        '1216', '984', '792', '1076', '2438', '4944', '4074', '1218',
#        '4849', '4244', '4851', '1848', '3873', '4092', '773', '3550',
#        '3008', '419', '1098', '2090', '2101', '3393', '2738', '2437',
#        '143', '2262', '1182', '3661', '3732', '146', '451', '4596',
#        '1029', '1513', '2735', '346', '4688', '2405', '597', '598',
#        '3299', '4788', '1872', '1826', '4058', '316', '3952', '3163',
#        '4519', '913', '1684', '4515', '1276', '1279', '4921', '2537',
#        '2246', '3617', '3395', '2069', '2335', '386', '4274', '3147',
#        '1858', '362', '2010', '4010', '4666', '1609', '845', '4326',
#        '2874', '2068', '195', '872', '2158', '521', '4860', '3096',
#        '3154', '1415', '1758', '4346', '3440', '1197', '3707', '1514',
# ...

# %%
df.loc[df['clicks'] == 'missing']
# Out:
#       campaign_id      campaign_name      platform       date  impressions  \
# 990          1991                !!!        FB ads 2024-04-05      39376.0
# 991          1992                NaN  Facebook Ads 2024-03-10      36617.0
# 992          1993        Summer Sale    Google Ads 2024-03-10      10282.0
# 993          1994      Holiday Offer           NaN 2024-02-15      35903.0
# 994          1995   Unknown_campaign       Unknown 2024-01-01      45312.0
# 995          1996        Summer Sale    Google Ads 2024-02-15          NaN
# 996          1997   Unknown_campaign        FB ads 2024-04-05          NaN
# 997          1998  Black Friday Deal     Gogle Adz 2024-02-15          NaN
# 998          1999   Unknown_campaign    Google Ads 2024-02-15          NaN
# 999          2000                !!!     Gogle Adz 2024-04-05          NaN
# 1181         1992                NaN  Facebook Ads 2024-02-15      36617.0
#
# ...

# %%
# atta apalykade ase 11 rows ahet tyanchi value 'missing' ahe tya missing la null ne replace karayache.
# nantar column la string to int karayche 
# mg null value la mean ne fill karayache
df['clicks'] = df['clicks'].replace('missing', np.nan)

# %%
# Step 1: Convert to numeric (this will turn non-numeric like NaN or 'missing' into np.nan)
df['clicks'] = pd.to_numeric(df['clicks'], errors='coerce')
df['clicks'].dtype
# Out:
# dtype('float64')

# %%
# avg session duration che formating adhi karu mag sarv numeric column chya null value fill karu mean kinva median ne

# %%
df['avg_session_duration']
# Out:
# 0          NaN
# 1       2m 15s
# 2          NaN
# 3          NaN
# 4       3m 40s
#          ...
# 1195    3m 40s
# 1196       NaN
# 1197       NaN
# 1198       NaN
# 1199       NaN
# Name: avg_session_duration, Length: 1200, dtype: object

# %%
df['avg_session_duration'].unique()
# Out:
# array([nan, '2m 15s', '3m 40s'], dtype=object)

# %%
df['avg_session_duration'].isnull().sum()
# Out:
# np.int64(639)

# %%
df.head()
# Out:
#    campaign_id      campaign_name      platform       date  impressions  \
# 0         1001        Summer Sale       Unknown 2024-03-10      33144.0
# 1         1002                !!!  Facebook Ads 2024-02-15      32780.0
# 2         1003                NaN           NaN 2024-02-15      28847.0
# 3         1004        Summer Sale     Gogle Adz 2024-02-15      21367.0
# 4         1005  Black Friday Deal    Google Ads 2024-03-10      36303.0
#
#    clicks    cost  conversions  revenue    ctr  ...  conversion_rate   roas  \
# 0  1836.0  428.66        494.0  3697.13   5.54  ...            26.91   8.62
# 1  1846.0  431.54         97.0  1834.94   5.63  ...             5.25   4.25
# 2  3890.0   85.31        261.0  4562.69  13.48  ...             6.71  53.48
# 3  4922.0  449.65        146.0  2968.74  23.04  ...             2.97   6.60
# 4  4947.0  176.97        313.0  3103.35  13.63  ...             6.33  17.54
#
#       ad_type     audience_segment device_type   region bounce_rate  \
# ...

# %%
df['impressions']
# Out:
# 0       33144.0
# 1       32780.0
# 2       28847.0
# 3       21367.0
# 4       36303.0
#          ...
# 1195    36176.0
# 1196    37920.0
# 1197     8537.0
# 1198     7547.0
# 1199     7814.0
# Name: impressions, Length: 1200, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   campaign_id           1200 non-null   int64
#  1   campaign_name         1004 non-null   object
#  2   platform              1030 non-null   object
#  3   date                  1200 non-null   datetime64[ns]
#  4   impressions           1195 non-null   float64
#  5   clicks                1189 non-null   float64
#  6   cost                  1192 non-null   float64
#  7   conversions           1193 non-null   float64
#  8   revenue               1194 non-null   float64
#  9   ctr                   1189 non-null   float64
#  10  cpc                   1189 non-null   float64
#  11  conversion_rate       1189 non-null   float64
#  12  roas                  1192 non-null   float64
#  13  ad_type               979 non-null    object
# ...

# %%
q1=16173
q3=39147
iqr=q3-q1
lf=(q1)-1.5*(iqr)
lf
# Out:
# -18288.0

# %%
hf=q3+1.5*(iqr)
print(hf)
# Out:
# 73608.0

# %%
df.loc[df['impressions'] >= 73608.0]
# Out:
# Empty DataFrame
# Columns: [campaign_id, campaign_name, platform, date, impressions, clicks, cost, conversions, revenue, ctr, cpc, conversion_rate, roas, ad_type, audience_segment, device_type, region, bounce_rate, avg_session_duration, engagement_rate, ad_position]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.describe()
# Out:
#        campaign_id                 date   impressions       clicks  \
# count  1200.000000                 1200   1195.000000  1189.000000
# mean   1502.479167  2024-02-23 12:30:00  27658.066946  2565.777965
# min    1001.000000  2024-01-01 00:00:00   5054.000000   100.000000
# 25%    1250.750000  2024-02-15 00:00:00  16173.500000  1331.000000
# 50%    1505.000000  2024-03-10 00:00:00  27782.000000  2531.000000
# 75%    1749.250000  2024-03-10 00:00:00  39147.500000  3871.000000
# max    2000.000000  2024-04-05 00:00:00  49865.000000  4997.000000
# std     287.972886                  NaN  13083.905300  1448.510447
#
#               cost  conversions      revenue          ctr          cpc  \
# count  1192.000000  1193.000000  1194.000000  1189.000000  1189.000000
# mean    265.122659   249.744342  2778.121039    12.971985     0.228545
# min      50.200000    10.000000   508.070000     0.250000     0.010000
# 25%     140.575000   131.000000  1648.747500     4.960000     0.060000
# ...

# %%
# using count we can find null values. apan tharvu shakato konta column thevayacha konta nahi
# Mean आपल्याला सांगतो की कॉलममधला data सर्वसाधारणपणे कुठे केंद्रित आहे. जर mean आणि median मध्ये मोठा फरक असेल, तर डेटा skewed आहे (एकाच बाजूला झुकलेला).
# जर mean खूपच जास्त किंवा कमी वाटत असेल, तर कदाचित काही outlier values आहेत.
# Standard Deviation (std) म्हणजे डेटामधील विस्कळीतपणा (spread) किंवा values किती प्रमाणात mean पासून दूर आहेत ते मोजण्याचं एक मापदंड आहे.
# जर std कमी असेल तर सगळ्या values जवळपास आहेत.जर std जास्त असेल, तर काही values खूप जास्त किंवा कमी आहेत.
# std समजून घेतल्याशिवाय normalization किंवा standardization योग्य प्रकारे करता येत नाही.
# दोन कॉलममध्ये mean सारखा असला तरी ज्याचा std कमी आहे तो जास्त stable आणि विश्वासार्ह आहे.
# min आपल्याला सांगतो की त्या column मध्ये सर्वात कमी किंवा किमान कोणती value आहे.
# min- Outliers ओळखण्यासाठी (Too Low Values) कधी कधी एखादी value फारच कमी असते — आणि ती realistic वाटत नाही.
# उदा: Age कॉलमचा min = -5 असेल ⇒ चुकीचा डेटा आहे.
# min->Negative values जिथे नसाव्यात. Zero values जिथे अपेक्षित नाही. Extremely small numbers. Business Logic Validate करण्यासाठी
# 25% म्हणजे 1st Quartile (Q1) — हा डेटा मधील असा point आहे की 25% डेटा ह्याच्यापेक्षा कमी आहे आणि 75% डेटा ह्याच्यापेक्षा जास्त आहे.
# min, Q1, median, Q3, max हे एकत्र बघितल्यास डेटा कसा पसरलेला आहे ते समजतं.
# Outliers शोधण्यासाठी Q1 चा उपयोग फार महत्त्वाचा आहे.
# जर median (50%) आणि Q1 मध्ये मोठा फरक असेल, तर data skewed असू शकतो.
# 50% म्हणजे Median (मध्यमान) – हा डेटा मधला value आहे.म्हणजेच, डेटा ascending order मध्ये लावल्यावर, नक्की मधोमध येणारी value म्हणजे Median.
# 50%-Central Tendency समजण्यासाठी,Skewness (data झुकलेला आहे का?) समजण्यासाठी Median वर outliers चा प्रभाव कमी असतो.
# त्यामुळे जेव्हा dataset मध्ये outliers असतील तेव्हा median वापरणं योग्य असतं.
# 75% म्हणजे 3rd Quartile (Q3) – dataset मधील अशी value जिच्यापेक्षा 75% डेटा कमी आहे आणि 25% डेटा जास्त आहे.
# 75%->High Performers किंवा High Values segment शोधण्यासाठी

# %% [markdown]
# ## 1.2 Column Name Standardization
# Rename inconsistent, messy, or duplicate column names.

# %%
#df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %% [markdown]
# ## 1.3 Handling Missing Values (Nulls)

# %% [markdown]
# Drop rows:
# if condider over all dataset- जेव्हा missing rows फारच कमी असतात (जसं < 5%), तेव्हा drop करणं योग्य.
#
# Drop specific columns
# Too many nulls (> 50%)
#
# Fill with Mean / Median / Mode
# 1) For Numerical Columns-use mean and median(if outliers exist)
# 2) For Categorical Columns- use mode
#
# Forward Fill / Backward Fill-Time-series किंवा ordered data साठी वापरतात.
#
# Custom Values Fill-Business knowledge वापरून specific values टाकणे.
# ex- df['Age'].fillna(0, inplace=True)  # Age जर 0 असेल तर "Unknown"
#
# Predictive Imputation (Advanced)- Missing values predict करणं using ML (Linear Regression, KNN)

# %%
# df.dropna(inplace=True)  # सगळ्या rows जिथे missing आहे ते काढून टाक

# %% [markdown]
# ## 1.4 Handling Duplicate

# %% [markdown]
# ## 1.5 Handling Incorrect Data Types

# %% [markdown]
# ## 1.6 Outlier Detection & Treatment

# %% [markdown]
# ## 1.7 data formating

# %% [markdown]
# ## 1.8 Handling Invalid or Impossible Values
# Logical validation: Negative age? Spend more than revenue?
# Apply business rules.

# %% [markdown]
# ## 1.9 Text Cleaning
# Remove special characters, numbers, stopwords
#
# Lowercase, lemmatize

# %% [markdown]
# ## 1.10 correct spelling, replace, mapping

# %% [markdown]
# ## 1.11 data normalization,scalling

# %% [markdown]
# ## 1.12 data transformation-log, power

# %% [markdown]
# ## 1.13 feature engineering-date feature,word count,

# %%
dataset_name.corr(method='pearsons').head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 dataset_name.corr(method='pearsons').head(10)
#
# NameError: name 'dataset_name' is not defined

# %%
plt.scatterplot(x=dataset[c1],y=dataset[c2])

# %% [markdown]
# ## 1.14 Encoding

# %% [markdown]
# ## 1.15 data binning

# %% [markdown]
# ## 1.16 data sampling

# %% [markdown]
# ## 1.17 handling imbalanced data
