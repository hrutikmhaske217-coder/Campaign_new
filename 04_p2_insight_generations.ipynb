# %%
# 🔍 Insight Generation Report

# 🎯 Campaign Performance Insights

# High CTR Campaigns

# Campaigns with CTR > 5% were mostly associated with creative_type = Video and ad_position = Top.
# Video ads placed at the top performed significantly better in engaging users compared to Banner or Carousel formats.

# Low ROAS Campaigns
# Certain campaigns with high cost and low revenue had ROAS < 1.
# These campaigns were often targeted to audience_segment = General on the platform = Display.
# ✅ Actionable: Reallocate budget from low-performing Display campaigns to more profitable Search or Social channels.



# 👥 Audience Segment Insights

# High Engagement Segments
# audience_segment = Tech Enthusiasts had high engagement rates (avg > 0.35) and low bounce rates.
# This segment also showed higher conversion rates and customer lifetime value (CLV).
# ✅ Actionable: Increase ad frequency and personalized content targeting for this segment.



# Underperforming Segments

# audience_segment = Bargain Hunters had high impressions but low conversions, indicating poor message match or creative misfit.
# ✅ Actionable: Test different creatives and call-to-actions for this segment.



# 📱 Device & Platform Insights

# Device Type Impact
# device_type = Mobile had higher CTR and engagement rate but lower conversion rate than Desktop.
# Desktop users showed better purchasing intent (higher conversion rate and ROAS).
# ✅ Actionable: Use Mobile campaigns for awareness and Desktop campaigns for conversion targeting.



# Platform Efficiency

# platform = Social yielded better ROI (ROAS > 2) than Display.
# Search platform users were more likely to convert with higher average session durations.



# ⏳ Time-Based Insights

# Week-wise Performance
# Weeks 25–28 saw a spike in conversions, aligning with promotional periods or seasonal trends.
# Engagement rate increased on weekends but conversion rates dropped—users browse more, purchase less.
# ✅ Actionable: Schedule awareness campaigns on weekends and conversion-focused ads on weekdays.


# 💰 Spend & Revenue Correlation

# Ad Spend vs. Revenue
# Strong positive correlation (r ≈ 0.72) between cost and revenue, indicating ad spend efficiency.
# However, diminishing returns observed beyond a certain budget threshold (non-linear relationship).
# ✅ Actionable: Use ROAS thresholds to cap spending and maintain profitability.


# ⚙️ Feature Importance 

# Top predictive features for CTR category:
# creative_type
# ad_position
# platform
# engagement_rate
# device_type

# %%
# Key Dashboard Sections Based on Your Insights

# 1. Campaign Performance Overview
# KPIs: Total Impressions, Clicks, CTR, Conversions, Revenue, ROAS

# Visuals:
# Line chart: CTR trend over time
# Bar chart: ROAS per Campaign
# Matrix or table: CTR & ROAS by campaign_name and ad_type

# 2. Audience Segmentation Analysis

# Visuals:

# Bar/column chart: Engagement rate & conversion rate by audience_segment
# Stacked bar: CTR/Conversions split by audience segments
# Scatter plot: CLV vs CAC per audience segment

# 3. Device & Platform Analysis

# Visuals:

# Pie chart: CTR split by device_type
# Bar chart: ROAS by platform
# Clustered chart: Conversions by platform vs device

# 4. Time Series Analysis

# Visuals:

# Week-over-week line chart: Conversions & CTR
# Heatmap: Engagement Rate by Day of Week and Hour
# Timeline slicer: For user to filter week-wise performance

# 5. Spend & Revenue Efficiency

# Visuals:

# Scatter plot: Ad Spend vs Revenue (highlight diminishing returns)
# Gauge: ROAS level (with thresholds)
# KPI cards: Avg CPC, CAC, CLV

# 6. Top Performing Features (Based on Feature Importance)

# Visuals:

# Feature importance bar chart (from Random Forest)
# Dropdown filters to drill down by creative_type, ad_position, platform
